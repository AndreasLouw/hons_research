# %%
# !pip install torch torchvision
# !pip install datasets evaluate wandb
# !pip install git+https://github.com/huggingface/transformers
# !pip install wandb
# !pip install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 23.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 24.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.5/189.5 kB 21.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 20.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1tRz38DckvY3K437jd_jmml9las3le7pE' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1tRz38DckvY3K437jd_jmml9las3le7pE" -O cnn.py && rm -rf /tmp/cookies.txt
# Out:
# --2023-09-15 06:35:06--  https://docs.google.com/uc?export=download&confirm=&id=1tRz38DckvY3K437jd_jmml9las3le7pE
# Resolving docs.google.com (docs.google.com)... 108.177.126.113, 108.177.126.139, 108.177.126.101, ...
# Connecting to docs.google.com (docs.google.com)|108.177.126.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://accounts.google.com/ServiceLogin?service=wise&passive=1209600&continue=https://docs.google.com/uc?export%3Ddownload%26confirm%26id%3D1tRz38DckvY3K437jd_jmml9las3le7pE&followup=https://docs.google.com/uc?export%3Ddownload%26confirm%26id%3D1tRz38DckvY3K437jd_jmml9las3le7pE [following]
# --2023-09-15 06:35:06--  https://accounts.google.com/ServiceLogin?service=wise&passive=1209600&continue=https://docs.google.com/uc?export%3Ddownload%26confirm%26id%3D1tRz38DckvY3K437jd_jmml9las3le7pE&followup=https://docs.google.com/uc?export%3Ddownload%26confirm%26id%3D1tRz38DckvY3K437jd_jmml9las3le7pE
# ...

# %%
# Downlaod cnn script
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1tRz38DckvY3K437jd_jmml9las3le7pE' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1tRz38DckvY3K437jd_jmml9las3le7pE" -O cnn-mnist.py && rm -rf /tmp/cookies.txt

#https://drive.google.com/file/d/1tRz38DckvY3K437jd_jmml9las3le7pE/view?usp=drive_link
# Out:
# --2023-09-14 16:41:28--  https://docs.google.com/uc?export=download&confirm=&id=1tRz38DckvY3K437jd_jmml9las3le7pE
# Resolving docs.google.com (docs.google.com)... 64.233.189.138, 64.233.189.113, 64.233.189.101, ...
# Connecting to docs.google.com (docs.google.com)|64.233.189.138|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://accounts.google.com/ServiceLogin?service=wise&passive=1209600&continue=https://docs.google.com/uc?export%3Ddownload%26confirm%26id%3D1tRz38DckvY3K437jd_jmml9las3le7pE&followup=https://docs.google.com/uc?export%3Ddownload%26confirm%26id%3D1tRz38DckvY3K437jd_jmml9las3le7pE [following]
# --2023-09-14 16:41:28--  https://accounts.google.com/ServiceLogin?service=wise&passive=1209600&continue=https://docs.google.com/uc?export%3Ddownload%26confirm%26id%3D1tRz38DckvY3K437jd_jmml9las3le7pE&followup=https://docs.google.com/uc?export%3Ddownload%26confirm%26id%3D1tRz38DckvY3K437jd_jmml9las3le7pE
# ...

# %%
# !python vit-mnist.py \
    --model_type vit \
    --dataset_name mnist \
    --output_dir drive/MyDrive/hons-research/output/vit/mnist/mnist_outputs_1/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 64 \
    --per_device_eval_batch_size 64 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 1 \
    --seed 1 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# Streaming output truncated to the last 5000 lines.
#  73% 103/141 [00:28<00:10,  3.66it/s]
#  74% 104/141 [00:28<00:10,  3.66it/s]
#  74% 105/141 [00:28<00:09,  3.66it/s]
#  75% 106/141 [00:29<00:09,  3.67it/s]
#  76% 107/141 [00:29<00:09,  3.68it/s]
#  77% 108/141 [00:29<00:08,  3.67it/s]
#  77% 109/141 [00:30<00:08,  3.63it/s]
#  78% 110/141 [00:30<00:08,  3.62it/s]
#  79% 111/141 [00:30<00:08,  3.63it/s]
#  79% 112/141 [00:30<00:08,  3.50it/s]
#  80% 113/141 [00:31<00:07,  3.52it/s]
#  81% 114/141 [00:31<00:07,  3.50it/s]
#  82% 115/141 [00:31<00:07,  3.50it/s]
#  82% 116/141 [00:32<00:07,  3.50it/s]
#  83% 117/141 [00:32<00:06,  3.50it/s]
#  84% 118/141 [00:32<00:06,  3.51it/s]
#  84% 119/141 [00:32<00:06,  3.52it/s]
#  85% 120/141 [00:33<00:05,  3.53it/s]
#  86% 121/141 [00:33<00:05,  3.53it/s]
#  87% 122/141 [00:33<00:05,  3.51it/s]
#  87% 123/141 [00:34<00:05,  3.50it/s]
#  88% 124/141 [00:34<00:04,  3.50it/s]
#  89% 125/141 [00:34<00:04,  3.56it/s]
# ...

# %%
# !python vit-mnist.py \
    --model_type vit \
    --dataset_name mnist \
    --output_dir drive/MyDrive/hons-research/output/vit/mnist/mnist_outputs_2/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 64 \
    --per_device_eval_batch_size 64 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 2 \
    --seed 2 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# Streaming output truncated to the last 5000 lines.
#  73% 103/141 [00:28<00:10,  3.62it/s]
#  74% 104/141 [00:28<00:10,  3.62it/s]
#  74% 105/141 [00:28<00:09,  3.60it/s]
#  75% 106/141 [00:29<00:09,  3.60it/s]
#  76% 107/141 [00:29<00:09,  3.62it/s]
#  77% 108/141 [00:29<00:09,  3.62it/s]
#  77% 109/141 [00:30<00:08,  3.64it/s]
#  78% 110/141 [00:30<00:08,  3.63it/s]
#  79% 111/141 [00:30<00:08,  3.64it/s]
#  79% 112/141 [00:30<00:07,  3.63it/s]
#  80% 113/141 [00:31<00:07,  3.63it/s]
#  81% 114/141 [00:31<00:07,  3.65it/s]
#  82% 115/141 [00:31<00:07,  3.63it/s]
#  82% 116/141 [00:31<00:06,  3.59it/s]
#  83% 117/141 [00:32<00:06,  3.60it/s]
#  84% 118/141 [00:32<00:06,  3.62it/s]
#  84% 119/141 [00:32<00:06,  3.64it/s]
#  85% 120/141 [00:33<00:05,  3.64it/s]
#  86% 121/141 [00:33<00:05,  3.65it/s]
#  87% 122/141 [00:33<00:05,  3.65it/s]
#  87% 123/141 [00:33<00:04,  3.65it/s]
#  88% 124/141 [00:34<00:04,  3.63it/s]
#  89% 125/141 [00:34<00:04,  3.61it/s]
# ...

# %%
# !python vit-mnist.py \
    --model_type vit \
    --dataset_name mnist \
    --output_dir drive/MyDrive/hons-research/output/vit/mnist/mnist_outputs_3/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 64 \
    --per_device_eval_batch_size 64 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 3 \
    --seed 3 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# Streaming output truncated to the last 5000 lines.
#  73% 103/141 [00:28<00:10,  3.56it/s]
#  74% 104/141 [00:28<00:10,  3.57it/s]
#  74% 105/141 [00:29<00:10,  3.58it/s]
#  75% 106/141 [00:29<00:09,  3.58it/s]
#  76% 107/141 [00:29<00:09,  3.58it/s]
#  77% 108/141 [00:30<00:09,  3.59it/s]
#  77% 109/141 [00:30<00:08,  3.59it/s]
#  78% 110/141 [00:30<00:08,  3.60it/s]
#  79% 111/141 [00:30<00:08,  3.60it/s]
#  79% 112/141 [00:31<00:08,  3.60it/s]
#  80% 113/141 [00:31<00:07,  3.55it/s]
#  81% 114/141 [00:31<00:07,  3.53it/s]
#  82% 115/141 [00:32<00:07,  3.52it/s]
#  82% 116/141 [00:32<00:07,  3.54it/s]
#  83% 117/141 [00:32<00:06,  3.59it/s]
#  84% 118/141 [00:32<00:06,  3.55it/s]
#  84% 119/141 [00:33<00:06,  3.54it/s]
#  85% 120/141 [00:33<00:05,  3.53it/s]
#  86% 121/141 [00:33<00:05,  3.52it/s]
#  87% 122/141 [00:34<00:05,  3.49it/s]
#  87% 123/141 [00:34<00:05,  3.47it/s]
#  88% 124/141 [00:34<00:04,  3.46it/s]
#  89% 125/141 [00:34<00:04,  3.47it/s]
# ...

# %%
# !python vit-mnist.py \
    --model_type vit \
    --dataset_name mnist \
    --output_dir drive/MyDrive/hons-research/output/vit/mnist/mnist_outputs_4/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 64 \
    --per_device_eval_batch_size 64 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 4 \
    --seed 4 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# Streaming output truncated to the last 5000 lines.
#  44% 62/141 [00:17<00:22,  3.52it/s]
#  45% 63/141 [00:17<00:22,  3.53it/s]
#  45% 64/141 [00:18<00:21,  3.55it/s]
#  46% 65/141 [00:18<00:21,  3.56it/s]
#  47% 66/141 [00:18<00:21,  3.56it/s]
#  48% 67/141 [00:18<00:20,  3.58it/s]
#  48% 68/141 [00:19<00:20,  3.51it/s]
#  49% 69/141 [00:19<00:20,  3.46it/s]
#  50% 70/141 [00:19<00:20,  3.49it/s]
#  50% 71/141 [00:20<00:19,  3.52it/s]
#  51% 72/141 [00:20<00:19,  3.52it/s]
#  52% 73/141 [00:20<00:19,  3.52it/s]
#  52% 74/141 [00:20<00:18,  3.54it/s]
#  53% 75/141 [00:21<00:18,  3.52it/s]
#  54% 76/141 [00:21<00:18,  3.54it/s]
#  55% 77/141 [00:21<00:18,  3.55it/s]
#  55% 78/141 [00:22<00:17,  3.55it/s]
#  56% 79/141 [00:22<00:17,  3.56it/s]
#  57% 80/141 [00:22<00:17,  3.54it/s]
#  57% 81/141 [00:22<00:16,  3.56it/s]
#  58% 82/141 [00:23<00:16,  3.47it/s]
#  59% 83/141 [00:23<00:16,  3.47it/s]
#  60% 84/141 [00:23<00:16,  3.41it/s]
#  60% 85/141 [00:24<00:16,  3.42it/s]
# ...

# %%
# !python vit-mnist.py \
    --model_type vit \
    --dataset_name mnist \
    --output_dir drive/MyDrive/hons-research/output/vit/mnist/mnist_outputs_5/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 64 \
    --per_device_eval_batch_size 64 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 5 \
    --seed 5 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# Streaming output truncated to the last 5000 lines.
#  72% 102/141 [00:28<00:11,  3.45it/s]
#  73% 103/141 [00:28<00:11,  3.45it/s]
#  74% 104/141 [00:29<00:10,  3.43it/s]
#  74% 105/141 [00:29<00:10,  3.43it/s]
#  75% 106/141 [00:29<00:10,  3.43it/s]
#  76% 107/141 [00:30<00:09,  3.47it/s]
#  77% 108/141 [00:30<00:09,  3.51it/s]
#  77% 109/141 [00:30<00:09,  3.50it/s]
#  78% 110/141 [00:30<00:08,  3.54it/s]
#  79% 111/141 [00:31<00:08,  3.53it/s]
#  79% 112/141 [00:31<00:08,  3.55it/s]
#  80% 113/141 [00:31<00:07,  3.57it/s]
#  81% 114/141 [00:32<00:07,  3.54it/s]
#  82% 115/141 [00:32<00:07,  3.54it/s]
#  82% 116/141 [00:32<00:07,  3.54it/s]
#  83% 117/141 [00:32<00:06,  3.55it/s]
#  84% 118/141 [00:33<00:06,  3.54it/s]
#  84% 119/141 [00:33<00:06,  3.55it/s]
#  85% 120/141 [00:33<00:05,  3.57it/s]
#  86% 121/141 [00:33<00:05,  3.55it/s]
#  87% 122/141 [00:34<00:05,  3.54it/s]
#  87% 123/141 [00:34<00:05,  3.52it/s]
#  88% 124/141 [00:34<00:04,  3.52it/s]
# ...

# %%
# !python vit-mnist.py \
    --model_type vit \
    --dataset_name mnist \
    --output_dir drive/MyDrive/hons-research/output/vit/mnist/mnist_outputs_6/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 64 \
    --per_device_eval_batch_size 64 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 6 \
    --seed 6 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# Streaming output truncated to the last 5000 lines.
#  73% 103/141 [00:29<00:10,  3.52it/s]
#  74% 104/141 [00:29<00:10,  3.51it/s]
#  74% 105/141 [00:29<00:10,  3.52it/s]
#  75% 106/141 [00:30<00:09,  3.52it/s]
#  76% 107/141 [00:30<00:09,  3.54it/s]
#  77% 108/141 [00:30<00:09,  3.53it/s]
#  77% 109/141 [00:30<00:09,  3.53it/s]
#  78% 110/141 [00:31<00:08,  3.53it/s]
#  79% 111/141 [00:31<00:08,  3.55it/s]
#  79% 112/141 [00:31<00:08,  3.57it/s]
#  80% 113/141 [00:31<00:07,  3.56it/s]
#  81% 114/141 [00:32<00:07,  3.55it/s]
#  82% 115/141 [00:32<00:07,  3.54it/s]
#  82% 116/141 [00:32<00:07,  3.54it/s]
#  83% 117/141 [00:33<00:06,  3.55it/s]
#  84% 118/141 [00:33<00:06,  3.57it/s]
#  84% 119/141 [00:33<00:06,  3.56it/s]
#  85% 120/141 [00:33<00:05,  3.56it/s]
#  86% 121/141 [00:34<00:05,  3.57it/s]
#  87% 122/141 [00:34<00:05,  3.56it/s]
#  87% 123/141 [00:34<00:05,  3.54it/s]
#  88% 124/141 [00:35<00:04,  3.53it/s]
#  89% 125/141 [00:35<00:04,  3.53it/s]
# ...

# %%
# !python vit-mnist.py \
    --model_type vit \
    --dataset_name mnist \
    --output_dir drive/MyDrive/hons-research/output/vit/mnist/mnist_outputs_7/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 64 \
    --per_device_eval_batch_size 64 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 7 \
    --seed 7 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# Streaming output truncated to the last 5000 lines.
#  83% 117/141 [00:33<00:06,  3.56it/s]
#  84% 118/141 [00:33<00:06,  3.56it/s]
#  84% 119/141 [00:33<00:06,  3.56it/s]
#  85% 120/141 [00:34<00:05,  3.56it/s]
#  86% 121/141 [00:34<00:05,  3.56it/s]
#  87% 122/141 [00:34<00:05,  3.56it/s]
#  87% 123/141 [00:34<00:05,  3.55it/s]
#  88% 124/141 [00:35<00:04,  3.50it/s]
#  89% 125/141 [00:35<00:04,  3.49it/s]
#  89% 126/141 [00:35<00:04,  3.48it/s]
#  90% 127/141 [00:36<00:04,  3.49it/s]
#  91% 128/141 [00:36<00:03,  3.44it/s]
#  91% 129/141 [00:36<00:03,  3.45it/s]
#  92% 130/141 [00:36<00:03,  3.47it/s]
#  93% 131/141 [00:37<00:02,  3.45it/s]
#  94% 132/141 [00:37<00:02,  3.46it/s]
#  94% 133/141 [00:37<00:02,  3.48it/s]
#  95% 134/141 [00:38<00:02,  3.48it/s]
#  96% 135/141 [00:38<00:01,  3.47it/s]
#  96% 136/141 [00:38<00:01,  3.47it/s]
#  97% 137/141 [00:38<00:01,  3.48it/s]
#  98% 138/141 [00:39<00:00,  3.48it/s]
#  99% 139/141 [00:39<00:00,  3.48it/s]
# ...

# %%
# !python vit-mnist.py \
    --model_type vit \
    --dataset_name mnist \
    --output_dir drive/MyDrive/hons-research/output/vit/mnist/mnist_outputs_8/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 64 \
    --per_device_eval_batch_size 64 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 8 \
    --seed 8 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# Streaming output truncated to the last 5000 lines.
#  73% 103/141 [00:28<00:10,  3.57it/s]
#  74% 104/141 [00:28<00:10,  3.61it/s]
#  74% 105/141 [00:28<00:09,  3.64it/s]
#  75% 106/141 [00:29<00:09,  3.63it/s]
#  76% 107/141 [00:29<00:09,  3.66it/s]
#  77% 108/141 [00:29<00:09,  3.66it/s]
#  77% 109/141 [00:29<00:08,  3.67it/s]
#  78% 110/141 [00:30<00:08,  3.66it/s]
#  79% 111/141 [00:30<00:08,  3.68it/s]
#  79% 112/141 [00:30<00:07,  3.66it/s]
#  80% 113/141 [00:31<00:07,  3.64it/s]
#  81% 114/141 [00:31<00:07,  3.64it/s]
#  82% 115/141 [00:31<00:07,  3.65it/s]
#  82% 116/141 [00:31<00:06,  3.63it/s]
#  83% 117/141 [00:32<00:06,  3.65it/s]
#  84% 118/141 [00:32<00:06,  3.66it/s]
#  84% 119/141 [00:32<00:06,  3.65it/s]
#  85% 120/141 [00:32<00:05,  3.64it/s]
#  86% 121/141 [00:33<00:05,  3.66it/s]
#  87% 122/141 [00:33<00:05,  3.67it/s]
#  87% 123/141 [00:33<00:04,  3.69it/s]
#  88% 124/141 [00:34<00:04,  3.67it/s]
#  89% 125/141 [00:34<00:04,  3.65it/s]
# ...

# %%
# !python vit-mnist.py \
    --model_type vit \
    --dataset_name mnist \
    --output_dir drive/MyDrive/hons-research/output/vit/mnist/mnist_outputs_9/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 64 \
    --per_device_eval_batch_size 64 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 9 \
    --seed 9 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# Streaming output truncated to the last 5000 lines.
#  73% 103/141 [00:27<00:10,  3.78it/s]
#  74% 104/141 [00:27<00:09,  3.77it/s]
#  74% 105/141 [00:28<00:09,  3.78it/s]
#  75% 106/141 [00:28<00:09,  3.76it/s]
#  76% 107/141 [00:28<00:09,  3.77it/s]
#  77% 108/141 [00:28<00:08,  3.78it/s]
#  77% 109/141 [00:29<00:08,  3.80it/s]
#  78% 110/141 [00:29<00:08,  3.78it/s]
#  79% 111/141 [00:29<00:07,  3.76it/s]
#  79% 112/141 [00:29<00:07,  3.75it/s]
#  80% 113/141 [00:30<00:07,  3.71it/s]
#  81% 114/141 [00:30<00:07,  3.74it/s]
#  82% 115/141 [00:30<00:06,  3.73it/s]
#  82% 116/141 [00:31<00:06,  3.76it/s]
#  83% 117/141 [00:31<00:06,  3.78it/s]
#  84% 118/141 [00:31<00:06,  3.80it/s]
#  84% 119/141 [00:31<00:05,  3.70it/s]
#  85% 120/141 [00:32<00:05,  3.74it/s]
#  86% 121/141 [00:32<00:05,  3.75it/s]
#  87% 122/141 [00:32<00:05,  3.69it/s]
#  87% 123/141 [00:32<00:04,  3.72it/s]
#  88% 124/141 [00:33<00:04,  3.75it/s]
#  89% 125/141 [00:33<00:04,  3.76it/s]
# ...

# %%
# !python vit-mnist.py \
    --model_type vit \
    --dataset_name mnist \
    --output_dir drive/MyDrive/hons-research/output/vit/mnist/mnist_outputs_10/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 64 \
    --per_device_eval_batch_size 64 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 10 \
    --seed 10 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# Streaming output truncated to the last 5000 lines.
#  30% 42/141 [00:11<00:27,  3.65it/s]
#  30% 43/141 [00:11<00:26,  3.68it/s]
#  31% 44/141 [00:11<00:26,  3.70it/s]
#  32% 45/141 [00:12<00:25,  3.70it/s]
#  33% 46/141 [00:12<00:25,  3.68it/s]
#  33% 47/141 [00:12<00:25,  3.67it/s]
#  34% 48/141 [00:12<00:25,  3.68it/s]
#  35% 49/141 [00:13<00:25,  3.65it/s]
#  35% 50/141 [00:13<00:24,  3.65it/s]
#  36% 51/141 [00:13<00:24,  3.64it/s]
#  37% 52/141 [00:14<00:24,  3.67it/s]
#  38% 53/141 [00:14<00:24,  3.66it/s]
#  38% 54/141 [00:14<00:23,  3.69it/s]
#  39% 55/141 [00:14<00:23,  3.70it/s]
#  40% 56/141 [00:15<00:23,  3.69it/s]
#  40% 57/141 [00:15<00:22,  3.68it/s]
#  41% 58/141 [00:15<00:22,  3.70it/s]
#  42% 59/141 [00:15<00:22,  3.70it/s]
#  43% 60/141 [00:16<00:21,  3.71it/s]
#  43% 61/141 [00:16<00:21,  3.69it/s]
#  44% 62/141 [00:16<00:21,  3.68it/s]
#  45% 63/141 [00:17<00:21,  3.65it/s]
#  45% 64/141 [00:17<00:21,  3.67it/s]
#  46% 65/141 [00:17<00:20,  3.69it/s]
# ...

# %%
# End run

from google.colab import runtime
runtime.unassign()
