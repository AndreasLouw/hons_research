# %%
# !pip install torch torchvision
# !pip install datasets evaluate wandb
# !pip install git+https://github.com/huggingface/transformers
# !pip install wandb
# !pip install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.3/519.3 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 87.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.6/188.6 kB 25.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.8/218.8 kB 27.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1soxU5-6dls5krdoAu8DYOrje3LZg-EJM' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1soxU5-6dls5krdoAu8DYOrje3LZg-EJM" -O ip102.zip && rm -rf /tmp/cookies.txt

# !unzip ip102.zip -d data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/classification/val/29/23668.jpg
#   inflating: data/classification/val/29/23674.jpg
#   inflating: data/classification/val/29/23687.jpg
#   inflating: data/classification/val/29/23689.jpg
#   inflating: data/classification/val/29/23690.jpg
#   inflating: data/classification/val/29/23699.jpg
#   inflating: data/classification/val/29/23704.jpg
#   inflating: data/classification/val/29/23707.jpg
#   inflating: data/classification/val/29/23712.jpg
#   inflating: data/classification/val/29/23716.jpg
#   inflating: data/classification/val/29/23745.jpg
#   inflating: data/classification/val/29/23746.jpg
#   inflating: data/classification/val/29/23747.jpg
#   inflating: data/classification/val/29/23771.jpg
#   inflating: data/classification/val/29/23792.jpg
#   inflating: data/classification/val/29/23794.jpg
#   inflating: data/classification/val/29/23818.jpg
#   inflating: data/classification/val/29/23820.jpg
# ...

# %%
# Downlaod vit script
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1O4qmU3v8eGLQMAcvVa9qliN1qKcySrUE' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1O4qmU3v8eGLQMAcvVa9qliN1qKcySrUE" -O vit.py && rm -rf /tmp/cookies.txt

# https://drive.google.com/file/d/1O4qmU3v8eGLQMAcvVa9qliN1qKcySrUE/view?usp=sharing
# Out:
# --2023-09-05 18:03:15--  https://docs.google.com/uc?export=download&confirm=t&id=1O4qmU3v8eGLQMAcvVa9qliN1qKcySrUE
# Resolving docs.google.com (docs.google.com)... 64.233.170.113, 64.233.170.101, 64.233.170.138, ...
# Connecting to docs.google.com (docs.google.com)|64.233.170.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-00-bk-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/t88c69os3mm3vklfejefv2nb0sirie6g/1693936950000/11183032721846533402/*/1O4qmU3v8eGLQMAcvVa9qliN1qKcySrUE?e=download&uuid=527ea3e5-4a4e-4d14-a3c2-e216c2008a2b [following]
# ...
# --2023-09-05 18:03:15--  https://doc-00-bk-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/t88c69os3mm3vklfejefv2nb0sirie6g/1693936950000/11183032721846533402/*/1O4qmU3v8eGLQMAcvVa9qliN1qKcySrUE?e=download&uuid=527ea3e5-4a4e-4d14-a3c2-e216c2008a2b
# ...

# %%
# !python vit.py \
    --model_type vit \
    --train_dir data/classification/train \
    --validation_dir data/classification/test \
    --output_dir drive/MyDrive/hons-research/output/vit/ip102_outputs_1/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 1 \
    --seed 1 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-01 10:29:27.455416: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.9
# wandb: Run data is saved locally in /content/wandb/run-20230901_102932-wjdtvmsc
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run efficient-sky-1
# wandb: ⭐️ View project at https://wandb.ai/u15048366/colabVitIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/colabVitIp102/runs/wjdtvmsc
# 09/01/2023 10:29:33 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/01/2023 10:29:33 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# ...

# %%
# !python vit.py \
    --model_type vit \
    --train_dir data/classification/train \
    --validation_dir data/classification/test \
    --output_dir drive/MyDrive/hons-research/output/vit/ip102_outputs_2/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 2 \
    --seed 2 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-04 19:09:48.393267: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.9
# wandb: Run data is saved locally in /content/wandb/run-20230904_190952-dlarxz6s
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run drawn-frost-8
# wandb: ⭐️ View project at https://wandb.ai/u15048366/colabVitIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/colabVitIp102/runs/dlarxz6s
# 09/04/2023 19:09:54 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/04/2023 19:09:54 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# ...

# %%
# !python vit.py \
    --model_type vit \
    --train_dir data/classification/train \
    --validation_dir data/classification/test \
    --output_dir drive/MyDrive/hons-research/output/vit/ip102_outputs_3/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 3 \
    --seed 3 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-04 22:30:25.305062: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.9
# wandb: Run data is saved locally in /content/wandb/run-20230904_223029-mqhj3hpb
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run crimson-water-9
# wandb: ⭐️ View project at https://wandb.ai/u15048366/colabVitIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/colabVitIp102/runs/mqhj3hpb
# 09/04/2023 22:30:30 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/04/2023 22:30:30 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# ...

# %%
# !python vit.py \
    --model_type vit \
    --train_dir data/classification/train \
    --validation_dir data/classification/test \
    --output_dir drive/MyDrive/hons-research/output/vit/ip102_outputs_4/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 4 \
    --seed 4 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-05 01:50:33.085481: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.9
# wandb: Run data is saved locally in /content/wandb/run-20230905_015037-sao7ptgu
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run comic-paper-10
# wandb: ⭐️ View project at https://wandb.ai/u15048366/colabVitIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/colabVitIp102/runs/sao7ptgu
# 09/05/2023 01:50:38 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/05/2023 01:50:38 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# ...

# %%
# !python vit.py \
    --model_type vit \
    --train_dir data/classification/train \
    --validation_dir data/classification/test \
    --output_dir drive/MyDrive/hons-research/output/vit/ip102_outputs_5/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 5 \
    --seed 5 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-05 05:01:18.874988: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.9
# wandb: Run data is saved locally in /content/wandb/run-20230905_050123-9sjzjbkg
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run unique-sound-11
# wandb: ⭐️ View project at https://wandb.ai/u15048366/colabVitIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/colabVitIp102/runs/9sjzjbkg
# 09/05/2023 05:01:25 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/05/2023 05:01:25 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# ...

# %%
# !python vit.py \
    --model_type vit \
    --train_dir data/classification/train \
    --validation_dir data/classification/test \
    --output_dir drive/MyDrive/hons-research/output/vit/ip102_outputs_6/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 6 \
    --seed 6 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-05 08:34:50.974214: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.9
# wandb: Run data is saved locally in /content/wandb/run-20230905_083455-9fpx8ylt
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run sleek-water-12
# wandb: ⭐️ View project at https://wandb.ai/u15048366/colabVitIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/colabVitIp102/runs/9fpx8ylt
# 09/05/2023 08:34:57 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/05/2023 08:34:57 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# ...

# %%
# !python vit.py \
    --model_type vit \
    --train_dir data/classification/train \
    --validation_dir data/classification/test \
    --output_dir drive/MyDrive/hons-research/output/vit/ip102_outputs_7/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 7 \
    --seed 7 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-05 18:03:23.090072: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.9
# wandb: Run data is saved locally in /content/wandb/run-20230905_180328-6qeos5hu
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run comic-capybara-19
# wandb: ⭐️ View project at https://wandb.ai/u15048366/colabVitIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/colabVitIp102/runs/6qeos5hu
# 09/05/2023 18:03:29 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/05/2023 18:03:29 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# ...

# %%
# !python vit.py \
    --model_type vit \
    --train_dir data/classification/train \
    --validation_dir data/classification/test \
    --output_dir drive/MyDrive/hons-research/output/vit/ip102_outputs_8/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 8 \
    --seed 8 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-05 21:46:20.108795: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.9
# wandb: Run data is saved locally in /content/wandb/run-20230905_214624-g44c19kw
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run worldly-plant-20
# wandb: ⭐️ View project at https://wandb.ai/u15048366/colabVitIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/colabVitIp102/runs/g44c19kw
# 09/05/2023 21:46:25 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/05/2023 21:46:25 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# ...

# %%
# !python vit.py \
    --model_type vit \
    --train_dir data/classification/train \
    --validation_dir data/classification/test \
    --output_dir drive/MyDrive/hons-research/output/vit/ip102_outputs_9/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 9 \
    --seed 9 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-06 00:44:52.403594: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.9
# wandb: Run data is saved locally in /content/wandb/run-20230906_004456-0f4eo7jw
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run likely-cosmos-21
# wandb: ⭐️ View project at https://wandb.ai/u15048366/colabVitIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/colabVitIp102/runs/0f4eo7jw
# 09/06/2023 00:44:58 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/06/2023 00:44:58 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# ...

# %%
# !python vit.py \
    --model_type vit \
    --train_dir data/classification/train \
    --validation_dir data/classification/test \
    --output_dir drive/MyDrive/hons-research/output/vit/ip102_outputs_10/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 10 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --save_steps 500 \
    --data_seed 10 \
    --seed 10 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-06 04:05:38.864769: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.9
# wandb: Run data is saved locally in /content/wandb/run-20230906_040543-arsw5vpa
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run gallant-bird-22
# wandb: ⭐️ View project at https://wandb.ai/u15048366/colabVitIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/colabVitIp102/runs/arsw5vpa
# 09/06/2023 04:05:44 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/06/2023 04:05:44 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# ...

# %%
from google.colab import runtime
runtime.unassign()
