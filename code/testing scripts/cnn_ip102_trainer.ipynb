# %%
# !pip install torch torchvision
# !pip install datasets evaluate wandb
# !pip install git+https://github.com/huggingface/transformers
# !pip install wandb
# !pip install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 58.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 26.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 35.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 24.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 25.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Downlaod and extract ip102 data
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=12cjuc1ouU1zkoUzPf1n7vvawVnDszZy7' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=12cjuc1ouU1zkoUzPf1n7vvawVnDszZy7" -O ip102.zip && rm -rf /tmp/cookies.txt
# https://drive.google.com/file/d/12cjuc1ouU1zkoUzPf1n7vvawVnDszZy7/view?usp=drive_link
# !unzip ip102.zip -d data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/train/84/62445.jpg
#   inflating: data/train/84/62446.jpg
#   inflating: data/train/84/62448.jpg
#   inflating: data/train/84/62449.jpg
#   inflating: data/train/84/62450.jpg
#   inflating: data/train/84/62451.jpg
#   inflating: data/train/84/62452.jpg
#   inflating: data/train/84/62455.jpg
#   inflating: data/train/84/62456.jpg
#   inflating: data/train/84/62457.jpg
#   inflating: data/train/84/62459.jpg
#   inflating: data/train/84/62460.jpg
#   inflating: data/train/84/62462.jpg
#   inflating: data/train/84/62463.jpg
#   inflating: data/train/84/62465.jpg
#   inflating: data/train/84/62466.jpg
#   inflating: data/train/84/62467.jpg
#   inflating: data/train/84/62468.jpg
#   inflating: data/train/84/62469.jpg
#   inflating: data/train/84/62470.jpg
#   inflating: data/train/84/62473.jpg
#   inflating: data/train/84/62474.jpg
#   inflating: data/train/84/62475.jpg
#   inflating: data/train/84/62476.jpg
# ...

# %%
# Downlaod cnn script
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1RHCjl0B3hKDtftje-wzEJxkAkzF36GPo' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1RHCjl0B3hKDtftje-wzEJxkAkzF36GPo" -O cnn.py && rm -rf /tmp/cookies.txt

# https://drive.google.com/file/d/1RHCjl0B3hKDtftje-wzEJxkAkzF36GPo/view?usp=sharing

# %%
    # --dataset_name mnist \
    # --output_dir output/cnn/mnist/mnistoutputs_1/ \
    # --train_dir data/classification/train \

# !python cnn.py \
    --model_name microsoft/resnet-18 \
    --model_type resnet \
    --train_dir data/train \
    --validation_dir data/test \
    --output_dir drive/MyDrive/hons-research/outputs/cnn/ip102_outputs_1/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 100 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --data_seed 1 \
    --seed 1 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-28 07:01:08.454416: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.11
# wandb: Run data is saved locally in /content/wandb/run-20230928_070113-nv92s326
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run pretty-flower-4
# wandb: ⭐️ View project at https://wandb.ai/u15048366/cnnIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/cnnIp102/runs/nv92s326
# 09/28/2023 07:01:14 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/28/2023 07:01:14 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# ...

# %%
# End run

from google.colab import runtime
runtime.unassign()

# %%
# --train_dir drive/MyDrive/hons-research/data/ip102/train \
#     --validation_dir drive/MyDrive/hons-research/data/ip102/val \
#     --output_dir drive/MyDrive/hons-research/output/cnn/ip102/ip102outputs_1/ \

# drive/MyDrive/hons-research/script/cnn-run1.py \

# !python cnn.py \
    --model_name microsoft/resnet-18 \
    --model_type resnet \
    --train_dir data/train \
    --validation_dir data/test \
    --output_dir drive/MyDrive/hons-research/outputs/cnn/ip102_outputs_2/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 100 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --data_seed 2 \
    --seed 2 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-28 09:42:55.060819: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.11
# wandb: Run data is saved locally in /content/wandb/run-20230928_094259-zdb605ye
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run neat-flower-5
# wandb: ⭐️ View project at https://wandb.ai/u15048366/cnnIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/cnnIp102/runs/zdb605ye
# 09/28/2023 09:43:00 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/28/2023 09:43:00 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# ...

# %%
# !python cnn.py \
    --model_name microsoft/resnet-18 \
    --model_type resnet \
    --train_dir data/train \
    --validation_dir data/test \
    --output_dir drive/MyDrive/hons-research/outputs/cnn/ip102_outputs_3/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 100 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --data_seed 3 \
    --seed 3 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-28 12:30:37.732547: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.11
# wandb: Run data is saved locally in /content/wandb/run-20230928_123042-2og8kjjw
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run radiant-grass-6
# wandb: ⭐️ View project at https://wandb.ai/u15048366/cnnIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/cnnIp102/runs/2og8kjjw
# 09/28/2023 12:30:43 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/28/2023 12:30:43 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# ...

# %%
# !python cnn.py \
    --model_name microsoft/resnet-18 \
    --model_type resnet \
    --train_dir data/train \
    --validation_dir data/test \
    --output_dir drive/MyDrive/hons-research/outputs/cnn/ip102_outputs_4/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 100 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --data_seed 4 \
    --seed 4 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-28 18:33:43.729092: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.11
# wandb: Run data is saved locally in /content/wandb/run-20230928_183348-31cav3n7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run honest-bee-7
# wandb: ⭐️ View project at https://wandb.ai/u15048366/cnnIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/cnnIp102/runs/31cav3n7
# 09/28/2023 18:33:50 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/28/2023 18:33:50 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# ...

# %%
# !python cnn.py \
    --model_name microsoft/resnet-18 \
    --model_type resnet \
    --train_dir data/train \
    --validation_dir data/test \
    --output_dir drive/MyDrive/hons-research/outputs/cnn/ip102_outputs_5/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 100 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --data_seed 5 \
    --seed 5 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-28 20:38:35.603940: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.11
# wandb: Run data is saved locally in /content/wandb/run-20230928_203839-dz0wghqx
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fragrant-glitter-8
# wandb: ⭐️ View project at https://wandb.ai/u15048366/cnnIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/cnnIp102/runs/dz0wghqx
# 09/28/2023 20:38:41 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/28/2023 20:38:41 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# ...

# %%
# !python cnn.py \
    --model_name microsoft/resnet-18 \
    --model_type resnet \
    --train_dir data/train \
    --validation_dir data/test \
    --output_dir drive/MyDrive/hons-research/outputs/cnn/ip102_outputs_6/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 100 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --data_seed 6 \
    --seed 6 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-28 23:07:11.153423: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.11
# wandb: Run data is saved locally in /content/wandb/run-20230928_230715-2o8d5u2h
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run faithful-microwave-9
# wandb: ⭐️ View project at https://wandb.ai/u15048366/cnnIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/cnnIp102/runs/2o8d5u2h
# 09/28/2023 23:07:16 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/28/2023 23:07:16 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# ...

# %%
# !python cnn.py \
    --model_name microsoft/resnet-18 \
    --model_type resnet \
    --train_dir data/train \
    --validation_dir data/test \
    --output_dir drive/MyDrive/hons-research/outputs/cnn/ip102_outputs_7/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 100 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --data_seed 7 \
    --seed 7 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-29 01:48:36.966503: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.11
# wandb: Run data is saved locally in /content/wandb/run-20230929_014841-jb39499g
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run astral-surf-10
# wandb: ⭐️ View project at https://wandb.ai/u15048366/cnnIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/cnnIp102/runs/jb39499g
# 09/29/2023 01:48:42 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/29/2023 01:48:42 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# ...

# %%
# !python cnn.py \
    --model_name microsoft/resnet-18 \
    --model_type resnet \
    --train_dir data/train \
    --validation_dir data/test \
    --output_dir drive/MyDrive/hons-research/outputs/cnn/ip102_outputs_8/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 100 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --data_seed 8 \
    --seed 8 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-29 04:24:46.048534: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.11
# wandb: Run data is saved locally in /content/wandb/run-20230929_042450-7tafox4r
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run exalted-forest-11
# wandb: ⭐️ View project at https://wandb.ai/u15048366/cnnIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/cnnIp102/runs/7tafox4r
# 09/29/2023 04:24:51 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/29/2023 04:24:51 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# ...

# %%
# !python cnn.py \
    --model_name microsoft/resnet-18 \
    --model_type resnet \
    --train_dir data/train \
    --validation_dir data/test \
    --output_dir drive/MyDrive/hons-research/outputs/cnn/ip102_outputs_9/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 100 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --data_seed 9 \
    --seed 9 \
    --report_to wandb \
    --ignore_mismatched_sizes
# Out:
# 2023-09-29 07:06:24.030559: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: u15048366. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.11
# wandb: Run data is saved locally in /content/wandb/run-20230929_070628-fndsusav
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run floral-forest-12
# wandb: ⭐️ View project at https://wandb.ai/u15048366/cnnIp102
# wandb: 🚀 View run at https://wandb.ai/u15048366/cnnIp102/runs/fndsusav
# 09/29/2023 07:06:29 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 09/29/2023 07:06:29 - INFO - __main__ - Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# ...

# %%
# !python cnn.py \
    --model_name microsoft/resnet-18 \
    --model_type resnet \
    --train_dir data/train \
    --validation_dir data/test \
    --output_dir drive/MyDrive/hons-research/outputs/cnn/ip102_outputs_10/ \
    --remove_unused_columns False \
    --do_train \
    --do_eval \
    --push_to_hub False \
    --optim adamw_torch \
    --learning_rate 0.001 \
    --num_train_epochs 300 \
    --per_device_train_batch_size 256 \
    --per_device_eval_batch_size 256 \
    --logging_strategy steps \
    --logging_steps 100 \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --data_seed 10 \
    --seed 10 \
    --report_to wandb \
    --ignore_mismatched_sizes

# %%
# End run

from google.colab import runtime
runtime.unassign()
